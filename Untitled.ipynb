# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xtest = np.linspace(0, 100)
plt.plot(xtest)

# %%
y = np.exp(xtest)
# plt.plot(y)
plt.plot(np.log(y + 50))

# %%
np.exp(-4)
# Out:
# 0.01831563888873418
