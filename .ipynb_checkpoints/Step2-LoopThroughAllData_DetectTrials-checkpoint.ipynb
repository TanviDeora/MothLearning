# %%
import pandas as pd
import os
import numpy as np
# import matplotlib.pyplot as plt
from scipy import signal

# %%
# calculate transition from pixelNumThreshold

def transition(NumPixel):
    NumPixel = np.asarray(NumPixel)
    PixelNumThreshold = 500
    motion = (NumPixel > PixelNumThreshold)
    FrameIdx = np.array(range(len(motion)-1))
    mothIN = FrameIdx[motion[1:] & ~motion[:-1]]+1
    mothOUT = FrameIdx[~motion[1:] & motion[:-1]]+1
    return(mothIN, mothOUT)


def smooth(Pixels):
    win_gauss = signal.gaussian(10,3)
    smooth_Pixels = signal.convolve(Pixels, win_gauss, mode='same', method = 'direct') / win_gauss.sum()
    return(smooth_Pixels)

# %%
path = 'D:\\Moth Learning Project\\Flower shape Experiment Data\\Output\\Step1_Raw_DetectMotion'
data_files = [(os.path.join(root, name), name[0:-4])
               for root, dirs, files in os.walk(path)
               for name in files
               if name.endswith('.csv')]
len(data_files)
# Out:
# 50

# %%
for video in data_files:
    # read the details of the file and load the csv data
    filename = video[1]
    print('working on ' + filename)
    with open('Step2_SummaryFile.txt', 'a') as log_text:
        log_text.write('\n' + 'working on ' + filename + '\n')
    df = pd.read_csv(video[0])
    
    PixelCount = np.asarray(df.NumPixel)
    Smoothened_PixelCount = smooth(PixelCount) # smoothen the Numpixels across frames
    In,Out = transition(Smoothened_PixelCount) # pull out the moth going in and out of the frame
    
    if In.size > Out.size:
        In = In[:Out.size]
    elif Out.size > In.size: 
        Out = Out[1:]
    
    FramesMothInView = Out - In
    
    #save the data in a new dataframe
    d = {'MothIN': In, 'MothOut': Out, "FramesInView" : FramesMothInView}
    new_df = pd.DataFrame(data=d)
    cols = new_df.columns.tolist()
    cols[0], cols[1], cols[2] = cols[1], cols[2], cols[0]
    new_df = new_df.reindex(columns= cols)

    # save the newDf in a separte csv file
    outPath_data = "D:/Moth Learning Project/Flower shape Experiment Data/Output/Step2_DetectMothINOUT/"
    new_df.to_csv(outPath_data + filename + '_MothInOut.csv')
    
    if FramesMothInView.size==0:
        print(filename + " has no moth movement")
        with open('Step2_SummaryFile.txt', 'a') as log_text:
            log_text.write(filename + " has no moth movement" + '\n')
    else:
        # export figure for histogram
        binwidth = 50
        fig, ax = plt.subplots(1,1, figsize = (10,6))
        plt.hist(FramesMothInView, bins=range(min(FramesMothInView), max(FramesMothInView) + binwidth, binwidth))
        plt.xlabel("Total frames moth in view", fontsize = 20)
        plt.ylabel("Occurance of each bin", fontsize = 20)

        outPath_fig = 'D:/Moth Learning Project/Flower shape Experiment Data/Output/FigureForOccupancyTime/'
        plt.savefig(outPath_fig + filename + '_histogram.png')

        print('done with ' + filename)
        with open('Step2_SummaryFile.txt', 'a') as log_text:
            log_text.write('done with ' + filename + '\n')
# Out:
# working on c-10_m1
# done with c-10_m1
# working on c-10_m10
# done with c-10_m10
# working on c-10_m11
# done with c-10_m11
# working on c-10_m12
# done with c-10_m12
# working on c-10_m13
# done with c-10_m13
# working on c-10_m14
# done with c-10_m14
# working on c-10_m15
# done with c-10_m15
# working on c-10_m2
# done with c-10_m2
# working on c-10_m3
# done with c-10_m3
# working on c-10_m4
# done with c-10_m4
# working on c-10_m6
# done with c-10_m6
# working on c-10_m7
# done with c-10_m7
# working on c-10_m8
# done with c-10_m8
# working on c-10_m9
# done with c-10_m9
# working on c-1_m1
# done with c-1_m1
# working on c-1_m10
# done with c-1_m10
# working on c-1_m11
# done with c-1_m11
# working on c-1_m12
# c-1_m12 has no moth movement
# working on c-1_m13
# done with c-1_m13
# working on c-1_m14
# done with c-1_m14
# working on c-1_m15
# done with c-1_m15
# working on c-1_m2
# done with c-1_m2
# working on c-1_m3
# done with c-1_m3
# working on c-1_m5
# done with c-1_m5
# working on c-1_m6
# done with c-1_m6
# working on c-1_m7
# done with c-1_m7
# working on c-1_m8
# done with c-1_m8
# working on c-1_m9
# done with c-1_m9
# working on c-2_m1
# done with c-2_m1
# working on c-2_m10
# done with c-2_m10
# working on c-2_m11
# done with c-2_m11
# working on c-2_m12
# done with c-2_m12
# working on c-2_m2
# done with c-2_m2
# working on c-2_m3
# done with c-2_m3
# working on c-2_m5
# done with c-2_m5
# working on c-2_m6
# done with c-2_m6
# working on c-2_m7
# done with c-2_m7
# working on c-2_m8
# done with c-2_m8
# working on c-2_m9
# done with c-2_m9
# working on c-3_m1
# done with c-3_m1
# working on c-3_m10
# done with c-3_m10
# working on c-3_m11
# done with c-3_m11
# working on c-3_m12
# done with c-3_m12
# working on c-3_m13
# done with c-3_m13
# working on c-3_m2
# done with c-3_m2
# working on c-3_m3
# done with c-3_m3
# working on c-3_m6
# done with c-3_m6
# working on c-3_m7
# done with c-3_m7
# working on c-3_m8
# done with c-3_m8
# working on c-3_m9
# done with c-3_m9
