# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from scipy.optimize import curve_fit
from scipy import stats
import os
import numpy as np
import glob

# %%
def KL(P,Q, epsilon):
    
    # """ Epsilon is used here to avoid conditional code for
    # checking that neither P nor Q is equal to 0. """
    #      epsilon = 1e-20
    
    P = P+epsilon
    Q = Q+epsilon
    divergence = np.sum(P*np.log2(P/Q))
    return divergence

# %%
def plotCummulative(subset):
    import matplotlib.cm as cm
    colors = cm.jet(np.linspace(0, 1, len(bin_id)))

    flowershape = ['c1', 'c2', 'c3', 'c10']
#     subset = [subset_c1, subset_c2, subset_c3, subset_c10]

    fig, ax = plt.subplots(1,len(subset), figsize=(20,6))
    for shape, i in zip(subset,range(len(ax))):
        data = shape
        cc = 0
        for bin in bin_id:
            value, base = np.histogram(data.loc[data.myBin == bin, 'DiscoveryTime'].values/100,
                      bins, density = True)
            cummulative = np.cumsum(value)
            ax[i].plot(base[:-1], cummulative, label = bin, color = colors[cc])
            ax[i].set_title(flowershape[i])
            cc+=1

    plt.legend(bbox_to_anchor=(1.0, 1.0))
    return ax

# %%
outpath_fig = './dataFolders/Output/Figures/ExponentionalFitWithBounds/'
path = './dataFolders/Output/Step6_FloralTypeConsolidatedData_AndFitParameters/'

# %%
# Fix the bin number and edges based on ALL the data pooled together
shapes = ['c-1', 'c-2', 'c-3', 'c-10']
AllShapes = pd.DataFrame([])

for floralShape in shapes:
    file = glob.glob(path + floralShape + '_Alltrials.csv')[0]
    data = pd.read_csv(file)
    AllShapes = AllShapes.append(data)

# %% [markdown]
# ### bin the data in sets of three

# %%
AllShapes.loc[:,'trialNum'] = AllShapes.loc[:,'trialNum']+1

# %%
# bin in three's 

binsize = 3
bin = np.arange(0,40, binsize)
bin = np.append(bin,max(AllShapes['trialNum'])+1)
label = [str(i) for i in bin][1:]

AllShapes['binnedBy3s']=pd.cut(AllShapes['trialNum'], bin, labels = label)
AllShapes.head()
# Out:
#    Unnamed: 0  MothIn  MothOut  ProboscisDetect  DiscoveryTime  trialNum  \
# 0           0   31485    33858          31825.0          340.0         1
# 1           1   35183    36433          35616.0          433.0         2
# 2           2   37230    37741          37351.0          121.0         3
# 3           3   37830    38106              NaN            NaN         4
# 4           4   38344    38965          38438.0           94.0         5
#
#       name binnedBy3s
# 0  c-1_m10          3
# 1  c-1_m10          3
# 2  c-1_m10          3
# 3  c-1_m10          6
# 4  c-1_m10          6

# %%
# add a label for flower type
test = AllShapes['name'].str.split('_', n = 1, expand = True)
AllShapes.loc[:,'flower'] = test[0]

# %% [markdown]
# ### plot the binned data by not in sets of 3s but as 0 to that bin edge

# %%
binsize = 3
binning = np.arange(0,40, binsize)
binning = np.append(binning,max(AllShapes['trialNum'])+1)
binning = binning[::-1]

for bin in binning:
    AllShapes.loc[AllShapes.trialNum < bin + 1, 'cumBinnedBy3s'] = str(bin)

AllShapes.tail()
# Out:
#      Unnamed: 0  MothIn  MothOut  ProboscisDetect  DiscoveryTime  trialNum  \
# 740         740   97476    98118              NaN            NaN        15
# 741         741   98944    99206              NaN            NaN        16
# 742         742  100730   103133              NaN            NaN        17
# 743         743  104164   104783              NaN            NaN        18
# 744         744  105430   105898              NaN            NaN        19
#
#         name binnedBy3s flower cumBinnedBy3s
# 740  c-10_m9         15   c-10            15
# 741  c-10_m9         18   c-10            18
# 742  c-10_m9         18   c-10            18
# 743  c-10_m9         18   c-10            18
# 744  c-10_m9         21   c-10            21

# %% [markdown]
# ### Remove nan to calculate the zscore

# %%
AllShapes_notnull = AllShapes[AllShapes.DiscoveryTime.notnull()].copy()
z = np.abs(stats.zscore(AllShapes_notnull.DiscoveryTime.values))
outlier_ID = z > 5 
plt.plot(z, 'o') 

AllShapes_notnull.loc[:,'zscore'] = pd.Series(data = z, index = AllShapes_notnull.index)
AllShapes_notnull.loc[:,'outlier_ID'] = pd.Series(data = outlier_ID, index = AllShapes_notnull.index)

# %%
AllShapes_notnull.to_csv(path+'notnull_All_Data.csv')

# %%
# import seaborn as sns
# sns.__version__
# ax = sns.scatterplot(x = None, y = 'DiscoveryTime', hue = 'outlier_ID', data = AllShapes_notnull)

ValuesConsidered = AllShapes_notnull.loc[:, 'DiscoveryTime'].values/100

# outliers = AllShapes_notnull.loc[AllShapes_notnull.outlier_ID == True, 'DiscoveryTime'].values/100
# notoutliers = AllShapes_notnull.loc[AllShapes_notnull.outlier_ID == False, 'DiscoveryTime'].values/100

plt.plot(AllShapes_notnull.loc[AllShapes_notnull.outlier_ID == True, 'DiscoveryTime'].values/100,
         'o', color = 'red')
plt.plot(AllShapes_notnull.loc[AllShapes_notnull.outlier_ID == False, 'DiscoveryTime'].values/100,
         'o', color = 'blue')
plt.show()

plt.plot(ValuesConsidered, 'o', color = 'red')
plt.show()

# %% [markdown]
# ### Try to merge all both df

# %%
# AllShapes.loc[:, 'zscore'] = np.nan
# AllShapes.loc[:,'outlier_ID'] = np.nan

# %%
# print(AllShapes.shape, AllShapes_notnull.shape)
# Out:
# (2781, 9) (1647, 9)

# %%
# uber_df = pd.merge(AllShapes,
#                   AllShapes_notnull)
# print(uber_df.shape)
# uber_df.head()

# %% [markdown]
# # plot histogram for different bins

# %%
notoutliers = AllShapes_notnull.loc[AllShapes_notnull['outlier_ID'] == False].copy()

# %%
hist, bins = np.histogram(notoutliers['DiscoveryTime'].values/100, bins = 25)

fig, ax = plt.subplots(2,4, figsize = (20,6))
ax = ax.ravel()

ax[0].hist(notoutliers['DiscoveryTime'].values/100,
           bins, density = True, orientation = 'horizontal')
ax[4].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-1_')].values/100, 
           bins, density = True, orientation = 'horizontal' )
ax[5].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-2_')].values/100,
           bins, density = True, orientation = 'horizontal')
ax[6].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-3_')].values/100,
           bins, density = True, orientation = 'horizontal')
ax[7].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-10_')].values/100,
           bins, density = True, orientation = 'horizontal')
# Out:
# (array([0.05847722, 0.14394392, 0.10795794, 0.08996495, 0.05847722,
#         0.04048423, 0.06747371, 0.02249124, 0.01799299, 0.03148773,
#         0.01349474, 0.01349474, 0.01799299, 0.01349474, 0.00899649,
#         0.        , 0.        , 0.        , 0.        , 0.00899649,
#         0.00449825, 0.        , 0.        , 0.        , 0.00449825]),
#  array([1.00000e-02, 1.39080e+00, 2.77160e+00, 4.15240e+00, 5.53320e+00,
#         6.91400e+00, 8.29480e+00, 9.67560e+00, 1.10564e+01, 1.24372e+01,
#         1.38180e+01, 1.51988e+01, 1.65796e+01, 1.79604e+01, 1.93412e+01,
#         2.07220e+01, 2.21028e+01, 2.34836e+01, 2.48644e+01, 2.62452e+01,
#         2.76260e+01, 2.90068e+01, 3.03876e+01, 3.17684e+01, 3.31492e+01,
#         3.45300e+01]),
#  <a list of 25 Patch objects>)

# %%
# across flowers compare across bins

subset_c1 = notoutliers.loc[notoutliers.flower == 'c-1', ['DiscoveryTime', 'binnedBy3s']].copy()
subset_c2 = notoutliers.loc[notoutliers.flower == 'c-2', ['DiscoveryTime', 'binnedBy3s']].copy()
subset_c3 = notoutliers.loc[notoutliers.flower == 'c-3', ['DiscoveryTime', 'binnedBy3s']].copy()
subset_c10 = notoutliers.loc[notoutliers.flower == 'c-10', ['DiscoveryTime', 'binnedBy3s']].copy()

subset_c10.tail()
# Out:
#      DiscoveryTime binnedBy3s
# 729          214.0          6
# 732          713.0          9
# 733          908.0          9
# 735          250.0         12
# 737          580.0         12

# %%
# from cycler import cycler
# import matplotlib as mpl
import matplotlib.cm as cm

fig, ax = plt.subplots(1,4, figsize = (20,6))

bin_id = notoutliers.binnedBy3s.unique()

colors = cm.jet(np.linspace(0, 1, len(bin_id)))
# Change default color cycle for each shape
# mpl.rcParams['axes.prop_cycle']= cycler(color = 'brg')
i = 0
for bin in bin_id:
    ax[0].hist(subset_c1.loc[subset_c1.binnedBy3s == bin, 'DiscoveryTime'].values/100,
              bins , density = True, histtype = 'step', 
               cumulative = True, label = bin, color = colors[i])
    ax[0].legend()
    i+=1

#     bins, density=True, histtype='step', color = 'darkorange',
#         cumulative=True, label='highLight', orientation = 'horizontal')

# %%
import matplotlib.cm as cm
colors = cm.jet(np.linspace(0, 1, len(bin_id)))

flowershape = ['c1', 'c2', 'c3', 'c10']
subset = [subset_c1, subset_c2, subset_c3, subset_c10]

fig, ax = plt.subplots(1,4, figsize=(20,6))
for shape, i in zip(subset,range(0,4)):
    data = shape
    cc = 0
    for bin in bin_id:
        value, base = np.histogram(data.loc[data.binnedBy3s == bin, 'DiscoveryTime'].values/100,
                  bins, density = True)
        cummulative = np.cumsum(value)
        ax[i].plot(base[:-1], cummulative, label = bin, color = colors[cc])
        ax[i].set_title(flowershape[i])
        cc+=1
    
plt.legend(bbox_to_anchor=(1.0, 1.0))    
#                           density = True, histtype = 'step',
#                cumulative = True, label = bin, color = colors[i])

# %%
# plot as box plots 

import seaborn as sns

fig, ax = plt.subplots(figsize = (20,6))

# Grouped boxplot
sns.boxplot(ax = ax, x="flower", y="DiscoveryTime", hue="binnedBy3s", data=notoutliers, palette="Set1")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# sns.plt.show()

# %% [markdown]
# ### plot the cummulative curves

# %%
# across flowers compare across cummulative bins

subset_c1 = notoutliers.loc[notoutliers.flower == 'c-1', ['DiscoveryTime', 'cumBinnedBy3s']].copy()
subset_c1.rename(columns = {'cumBinnedBy3s': 'myBin'}, inplace = True)
subset_c2 = notoutliers.loc[notoutliers.flower == 'c-2', ['DiscoveryTime', 'cumBinnedBy3s']].copy()
subset_c2.rename(index = str, columns = {'cumBinnedBy3s': 'myBin'}, inplace = True)
subset_c3 = notoutliers.loc[notoutliers.flower == 'c-3', ['DiscoveryTime', 'cumBinnedBy3s']].copy()
subset_c3.rename(index = str, columns = {'cumBinnedBy3s': 'myBin'}, inplace = True)
subset_c10 = notoutliers.loc[notoutliers.flower == 'c-10', ['DiscoveryTime', 'cumBinnedBy3s']].copy()
subset_c10.rename(index = str, columns = {'cumBinnedBy3s': 'myBin'}, inplace = True)
subset = [subset_c1, subset_c2, subset_c3, subset_c10]
plotCummulative(subset)
# subset_c1.head()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029C245DCD68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029C245F7DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029C274C34A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000029C273BFB38>],
#       dtype=object)

# %%
# across flowers compare across cummulative bins

subset_c1 = notoutliers.loc[notoutliers.flower == 'c-1', ['DiscoveryTime', 'trialNum']].copy()
subset_c2 = notoutliers.loc[notoutliers.flower == 'c-2', ['DiscoveryTime', 'trialNum']].copy()
subset_c3 = notoutliers.loc[notoutliers.flower == 'c-3', ['DiscoveryTime', 'trialNum']].copy()
subset_c10 = notoutliers.loc[notoutliers.flower == 'c-10', ['DiscoveryTime', 'trialNum']].copy()
subset = [subset_c1, subset_c2, subset_c3, subset_c10]

# %%
import matplotlib.cm as cm
colors = cm.jet(np.linspace(0, 1, len(bin_id)))

flowershape = ['c1', 'c2', 'c3', 'c10']
#     subset = [subset_c1, subset_c2, subset_c3, subset_c10]

bin_id = notoutliers.binnedBy3s.unique()

fig, ax = plt.subplots(1,len(subset), figsize=(20,6))
for shape, i in zip(subset,range(len(ax))):
    data = shape
    cc = 0
    for bin in bin_id:
        value, base = np.histogram(data.loc[(data.trialNum < int(bin) + 1), 'DiscoveryTime'].values/100,
                  bins, density = True)
        cummulative = np.cumsum(value)
        ax[i].plot(base[:-1], cummulative, label = bin, color = colors[cc])
        ax[i].set_title(flowershape[i])
        cc+=1
#         ax[i].set_xscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
flowershape[1]
# Out:
# 'c2'

# %%
import matplotlib.cm as cm
colors = cm.jet(np.linspace(0, 1, len(subset)))

flowershape = ['c1', 'c2', 'c3', 'c10']
#     subset = [subset_c1, subset_c2, subset_c3, subset_c10]

bin_id = notoutliers.binnedBy3s.unique()

row = int(np.ceil(len(bin_id)/4))

fig, ax = plt.subplots(row,4, figsize=(20,15))
ax = ax.ravel()
for bin, i in zip(bin_id,range(len(ax))):
    cc = 0
    for shape in subset:
        data = shape
        value, base = np.histogram(data.loc[(data.trialNum < int(bin) + 1), 'DiscoveryTime'].values/100,
                  bins, density = True)
        cummulative = np.cumsum(value)
        ax[i].plot(base[:-1], cummulative, label = flowershape[cc], color = colors[cc])
        ax[i].set_title(bin)
        print(i, cc, flowershape[cc])
        cc+=1
#         ax[i].set_xscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))
# Out:
# 0 0 c1
# 0 1 c2
# 0 2 c3
# 0 3 c10
# 1 0 c1
# 1 1 c2
# 1 2 c3
# 1 3 c10
# 2 0 c1
# 2 1 c2
# 2 2 c3
# 2 3 c10
# 3 0 c1
# 3 1 c2
# 3 2 c3
# 3 3 c10
# 4 0 c1
# 4 1 c2
# 4 2 c3
# 4 3 c10
# 5 0 c1
# 5 1 c2
# 5 2 c3
# 5 3 c10
# 6 0 c1
# 6 1 c2
# 6 2 c3
# 6 3 c10
# 7 0 c1
# 7 1 c2
# 7 2 c3
# 7 3 c10
# 8 0 c1
# 8 1 c2
# 8 2 c3
# 8 3 c10
# 9 0 c1
# 9 1 c2
# 9 2 c3
# 9 3 c10
# 10 0 c1
# 10
# No handles with labels found to put in legend.
#  1 c2
# 10 2 c3
# 10 3 c10
# 11 0 c1
# 11 1 c2
# 11 2 c3
# 11 3 c10
# 12 0 c1
# 12 1 c2
# 12 2 c3
# 12 3 c10
# 13 0 c1
# 13 1 c2
# 13 2 c3
# 13 3 c10

# %%
# plot histtogram, not cummulative one
import matplotlib.cm as cm
colors = cm.Dark2(np.linspace(0, 1, len(subset)))

flowershape = ['c1', 'c2', 'c3', 'c10']
#     subset = [subset_c1, subset_c2, subset_c3, subset_c10]

bin_id = notoutliers.binnedBy3s.unique()

row = int(np.ceil(len(bin_id)/4))

fig, ax = plt.subplots(row,4, figsize=(20,15))
ax = ax.ravel()
for bin, i in zip(bin_id,range(len(ax))):
    cc = 0
    for shape in subset:
        data = shape
#         value, base = np.histogram(data.loc[(data.trialNum < int(bin) + 1), 'DiscoveryTime'].values/100,
#                   bins, density = True)
        ax[i].hist(data.loc[(data.trialNum < int(bin) + 1), 'DiscoveryTime'].values/100,
              bins , density = True, histtype = 'step',
                   cumulative = False,
                   orientation = 'horizontal',
                   label = flowershape[cc], 
                   color = colors[cc],
                  alpha = 0.7,
                  linewidth = 2)
#         cummulative = np.cumsum(value)
#         ax[i].plot(base[:-1], cummulative, label = flowershape[cc], color = colors[cc])
        ax[i].set_title(bin)
        cc+=1
        
plt.legend(bbox_to_anchor=(1.0, 1.0))
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Do statistics on the different distributions

# %%
a = ['c1', 'c2', 'c3', 'c10']
b = list(bin_id)

tuples = [(p1, p2) for p1 in a for p2 in b]
# tuples
index = pd.MultiIndex.from_tuples(tuples, names=['flowerType', 'MaxVisitNumber'])
distributions = pd.Series(data = None, index=index)
distributions
# Out:
# flowerType  MaxVisitNumber
# c1          3                NaN
#             6                NaN
#             9                NaN
#             12               NaN
#             15               NaN
#             18               NaN
#             21               NaN
#             24               NaN
#             27               NaN
#             30               NaN
#             33               NaN
#             36               NaN
#             39               NaN
#             90               NaN
# c2          3                NaN
#             6                NaN
#             9                NaN
#             12               NaN
#             15               NaN
#             18               NaN
#             21               NaN
#             24               NaN
#             27               NaN
#             30               NaN
#             33               NaN
#             36               NaN
#             39               NaN
#             90               NaN
# c3          3                NaN
#             6                NaN
#             9                NaN
#             12               NaN
#             15               NaN
#             18               NaN
#             21               NaN
#             24               NaN
#             27               NaN
#             30               NaN
#             33               NaN
#             36               NaN
#             39               NaN
#             90               NaN
# c10         3                NaN
#             6                NaN
#             9                NaN
#             12               NaN
#             15               NaN
#             18               NaN
#             21               NaN
#             24               NaN
#             27               NaN
#             30               NaN
#             33               NaN
#             36               NaN
#             39               NaN
#             90               NaN
# dtype: float64

# %%
distributions = pd.DataFrame({'flowertype': ['c1'] * 14)

# %%
g = sns.FacetGrid(subset_c1, hue="binnedBy3s", palette="Set1")
g = (g.map(sns.distplot, "DiscoveryTime", hist=False, kde_kws = dict(cumulative = True)))

# %%
g = sns.FacetGrid(df, col='cols', hue="target", palette="Set1")
g = (g.map(sns.distplot, "vals", hist=False, kde = True, vertical = True))

# %%
# test seaborn distplot for this

subset = AllShapes_notnull.loc[:, ['flower', 'DiscoveryTime', 'binnedBy3s']].copy()
subset.head()
new = subset.pivot(index = 'binnedBy3s', columns = 'flower', values = 'DiscoveryTime')
new.head()
# df = subset.melt(['DiscoveryTime'], var_name='cols',  value_name='vals')
# g = sns.FacetGrid(df, col='cols', hue="target", palette="Set1")
# g = (g.map(sns.distplot, "vals", hist=False, kde = True, vertical = True))

# df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-33e61bb91dd0> in <module>()
#       3 subset = AllShapes_notnull.loc[:, ['flower', 'DiscoveryTime', 'binnedBy3s']].copy()
#       4 subset.head()
# ----> 5 new = subset.pivot(index = 'binnedBy3s', columns = 'flower', values = 'DiscoveryTime')
#       6 new.head()
#       7 # df = subset.melt(['DiscoveryTime'], var_name='cols',  value_name='vals')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5189         """
#    5190         from pandas.core.reshape.reshape import pivot
# -> 5191         return pivot(self, index=index, columns=columns, values=values)
#    5192
#    5193     _shared_docs['pivot_table'] = """
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in pivot(self, index, columns, values)
#     407             indexed = self._constructor_sliced(self[values].values,
#     408                                                index=index)
# --> 409     return indexed.unstack(columns)
#     410
#     411
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    2895         """
#    2896         from pandas.core.reshape.reshape import unstack
# -> 2897         return unstack(self, level, fill_value)
#    2898
#    2899     # ----------------------------------------------------------------------
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     493         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     494                                fill_value=fill_value,
# --> 495                                constructor=obj._constructor_expanddim)
#     496         return unstacker.get_result()
#     497
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     129
#     130         self._make_sorted_values_labels()
# --> 131         self._make_selectors()
#     132
#     133     def _make_sorted_values_labels(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     167
#     168         if mask.sum() < len(self.index):
# --> 169             raise ValueError('Index contains duplicate entries, '
#     170                              'cannot reshape')
#     171
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# plot bins as cummalative distributions

# %%
# ax[4].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-2_')].values, bins, histtype='step', cumulative=True,)
# ax[4].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-3_')].values, bins, histtype='step', cumulative=True,)
# ax[4].hist(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-10_')].values, bins, histtype='step', cumulative=True,)

# %%
ax = notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-1_')].plot.kde(label = 'c-1')
ax = notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-2_')].plot.kde(label = 'c-2')
ax = notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-3_')].plot.kde(label = 'c-3')
ax = notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-10_')].plot.kde(label = 'c-10')
ax.legend()

# %%
hist_c1, bin_edge_c1 = np.histogram(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-1_')].values,
                                                    bins = 15, density = True)                                                    
hist_c2, bin_edge_c2 = np.histogram(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-2_')].values,
                                                    bins = 15, density = True)
hist_c3, bin_edge_c3 = np.histogram(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-3_')].values,
                                                    bins = 15, density = True)
hist_c10, bin_edge_c10 = np.histogram(notoutliers.DiscoveryTime[notoutliers.name.str.contains('c-10_')].values,
                                                    bins = 15, density = True)

# %%
print(np.sum(hist_c1 * np.diff(bin_edge_c1)), 
      np.sum(hist_c2 * np.diff(bin_edge_c2)), 
      np.sum(hist_c3 * np.diff(bin_edge_c3)),
      np.sum(hist_c10 * np.diff(bin_edge_c10)))
# Out:
# 0.9999999999999998 1.0 0.9999999999999999 1.0

# %%
stats.entropy(pk = hist_c1 , qk = hist_c10, base=None)
# Out:
# inf

# %%
def KL(a, b):
    a = np.asarray(a, dtype=np.float)
    b = np.asarray(b, dtype=np.float)
    
    return np.sum(np.where(a != 0, a * np.log2(a / b), 0))

# %%
KL(hist_c1, hist_c2)
# Out:
# C:\Users\Tanvi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# C:\Users\Tanvi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# C:\Users\Tanvi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """
# inf

# %%
KL(hist_c1, hist_c1, 1e-10), KL(hist_c1, hist_c2, 1e-10), KL(hist_c1, hist_c3, 1e-10), KL(hist_c1, hist_c10, 1e-10)
# Out:
# (0.0, 0.0009177513427175846, 0.000852732170212705, 0.0018763123420315548)

# %%
KL(hist_c1, hist_c1, 1e-20), KL(hist_c1, hist_c2, 1e-20), KL(hist_c1, hist_c3, 1e-20), KL(hist_c1, hist_c10, 1e-20)
# Out:
# (0.0, 0.0015146411519145328, 0.0012506598647423213, 0.0022742394886133468)

# %%
KL(hist_c1, hist_c1, 1e-30), KL(hist_c1, hist_c2, 1e-30), KL(hist_c1, hist_c3, 1e-30), KL(hist_c1, hist_c10, 1e-30)
# Out:
# (0.0, 0.0021115307250717088, 0.0016485862468471053, 0.0026721658707181306)

# %%
allData_df = pd.read_csv(file[0])
allData_df.head()

# %%
# bin data in sets of three or five

shapes = ['c-1', 'c-2','c-3', 'c-10']

for floralShape in shapes:
        
    file  = glob.glob(outpath + floralShape + '_Alltrials.csv')
    allData_df = pd.read_csv(file[0])
    
    binsize = 5
    trial_label = []
    trials = []
    
    for binned in range(0, max(allData_df.trialNum.values), binsize):
        
        subset = allData_df[(allData_df.trialNum == binned) & (allData_df.trialNum < binned + binsize)]
        
        trials.extend(subset.DiscoveryTime.values)
        trial_label.extend([str(binned) + '-' + str(binned + binsize -1)]*len(subset.DiscoveryTime.values))
                
    binned_df = pd.DataFrame({'trial_label': trial_label,
                              'trials':trials})
    binned_df.to_csv('./dataFolders/Output/Step6_FloralTypeConsolidatedData_AndFitParameters/' +
                    'BinnedBy5s_Data_for_' + floralShape + '.csv')

# %%
shapes = ['c-1', 'c-2','c-3', 'c-10']
fig, ax = plt.subplots(4,1, sharex = True, sharey = True, figsize = (10,15))
ax = ax.ravel()

ctr = 0
for floralShape in shapes:
    binned_df = pd.read_csv(outpath + 'BinnedBy3s_Data_for_' + floralShape + '.csv')
    unique_label = binned_df.trial_label.unique()
    median = []
    for idx in unique_label:
        sub = binned_df[binned_df.trial_label == idx]
        ax[ctr].plot(sub.trial_label, sub.trials*1/100, 'ro', markersize = '2', alpha = 0.5)
        median.append(sub.trials.mean(skipna=True)*1/100)
    ax[ctr].plot(unique_label, median, c = 'blue', marker = '_', markersize = 12)
    ax[ctr].set_title(floralShape)
#     ax[ctr].set_ylabel('ExplorationTime(second)')
    
    ctr+=1
# ax[3].set_xticks(rotation=90)
fig.text(0.06, 0.5, 'ExplorationTime(second)',
        ha = 'center', va='center', rotation = 'vertical')
fig.text(0.5, 0.06, 'Trial Number',
        ha = 'center', va='center', rotation = 'horizontal')
plt.xticks(rotation = 45)
plt.savefig(outpath_fig + 'ExplorationTime_BinnedBy3s.png')

# %%
import seaborn as sns

shapes = ['c-1', 'c-2','c-3', 'c-10']
fig, ax = plt.subplots(4,1, sharex = True, sharey = True, figsize = (8,10))
ax = ax.ravel()

ctr = 0
for floralShape in shapes:
    binned_df = pd.read_csv(outpath + 'BinnedBy3s_Data_for_' + floralShape + '.csv')
    unique_label = binned_df.trial_label.unique()
    median = []
    for idx in unique_label:
        sub = binned_df[binned_df.trial_label == idx]
#         sns.swarmplot(x = 'trial_label', y = 'trials', data = sub, ax = ax[ctr] )
        ax[ctr].plot(sub.trial_label, sub.trials*1/100, 'ro', markersize = '2', alpha = 0.5, jitter)
        median.append(sub.trials.mean(skipna=True)*1/100)
    ax[ctr].plot(unique_label, median, c = 'blue', marker = '_', markersize = 12)
    ax[ctr].set_title(floralShape)
#     ax[ctr].set_ylabel('ExplorationTime(second)')
    
    ctr+=1
# ax[3].set_xticks(rotation=90)
fig.text(0.06, 0.5, 'ExplorationTime(second)',
        ha = 'center', va='center', rotation = 'vertical')
fig.text(0.5, 0.06, 'Trial Number',
        ha = 'center', va='center', rotation = 'horizontal')
plt.xticks(rotation = 45)
plt.savefig(outpath_fig + 'ExplorationTime_BinnedBy3s.png')

# %%
shapes = ['c-1', 'c-2','c-3', 'c-10']
fig, ax = plt.subplots(4,1, sharex = True, sharey = True, figsize = (20,10))
ax = ax.ravel()

ctr = 0
for floralShape in shapes:
    binned_df = pd.read_csv(outpath + 'Binned_Data_for_' + floralShape + '.csv')
    ax[ctr].errorbar(binned_df.trial_label, binned_df['median']/100, yerr = binned_df['std']/100)
    ctr+=1
