# %%
import pandas as pd
import numpy as np
import glob
from scipy import stats
import matplotlib.pyplot as plt

# %%
s = np.random.poisson(5, 800)
s.sort()
count, bins, ignored = plt.hist(s, 14, density=True)

# %%
trial = np.arange(len(s))
discoveryTime = s

df = pd.DataFrame({'trial': trial, 'DiscoveryTime': discoveryTime})
plt.scatter(df.trial, df.DiscoveryTime)

# %%
# randomly permute 


# calculate KL divergence for permuted bins

# calculate KL divergence for true distribution in df

# plot them together
